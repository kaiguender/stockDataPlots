# %% [markdown]
# # Packages

# %%
import requests
import json
import re
from collections import defaultdict

import numpy as np
import pandas as pd

import ipdb

from yfinance import *

# %%
Ticker
# Out:
# yfinance.ticker.Ticker

# %%
class plotTicker(Ticker):
    
    def __init__(self):
        super().__init__(self)
        
    def plot(self):
        pass

# %%
test = Ticker('GOOG')

# %%
test.get_cashflow().T
# Out:
#              Investments  Change To Liabilities  \
#
# 2021-12-31 -8.806000e+09           1.057000e+09
# 2020-12-31 -9.822000e+09           1.329000e+09
# 2019-12-31 -4.017000e+09           4.650000e+08
# 2018-12-31 -1.972000e+09           1.438000e+09
#
#             Total Cashflows From Investing Activities  Net Borrowings  \
#
# 2021-12-31                              -3.552300e+10   -1.236000e+09
# 2020-12-31                              -3.277300e+10    9.661000e+09
# 2019-12-31                              -2.949100e+10   -2.680000e+08
# 2018-12-31                              -2.850400e+10   -6.100000e+07
#
#             Total Cash From Financing Activities  \
#
# 2021-12-31                         -6.136200e+10
# 2020-12-31                         -2.440800e+10
# 2019-12-31                         -2.320900e+10
# 2018-12-31                         -1.317900e+10
#
#             Change To Operating Activities    Net Income  Change In Cash  \
#
# 2021-12-31                    7.140000e+09  7.603300e+10   -5.520000e+09
# 2020-12-31                    5.813000e+09  4.026900e+10    7.967000e+09
# 2019-12-31                    7.822000e+09  3.434300e+10    1.797000e+09
# 2018-12-31                    7.890000e+09  3.073600e+10    5.986000e+09
#
#             Repurchase Of Stock  Effect Of Exchange Rate  \
#
# 2021-12-31        -5.027400e+10             -287000000.0
# 2020-12-31        -3.114900e+10               24000000.0
# 2019-12-31        -1.839600e+10              -23000000.0
# 2018-12-31        -9.075000e+09             -302000000.0
#
#             Total Cash From Operating Activities  Depreciation  \
#
# 2021-12-31                          9.165200e+10  1.243000e+10
# 2020-12-31                          6.512400e+10  1.367900e+10
# 2019-12-31                          5.452000e+10  1.165100e+10
# 2018-12-31                          4.797100e+10  9.029000e+09
#
#             Other Cashflows From Investing Activities  \
#
# 2021-12-31                                541000000.0
# 2020-12-31                                 68000000.0
# 2019-12-31                                589000000.0
# 2018-12-31                                 98000000.0
#
#             Change To Account Receivables  \
#
# 2021-12-31                  -9.095000e+09
# 2020-12-31                  -6.524000e+09
# 2019-12-31                  -4.340000e+09
# 2018-12-31                  -2.169000e+09
#
#             Other Cashflows From Financing Activities  Change To Netincome  \
#
# 2021-12-31                              -9.852000e+09         4.712000e+09
# 2020-12-31                              -2.920000e+09         9.349000e+09
# 2019-12-31                              -4.545000e+09         7.707000e+09
# 2018-12-31                              -4.043000e+09         3.298000e+09
#
#             Capital Expenditures
#
# 2021-12-31         -2.464000e+10
# 2020-12-31         -2.228100e+10
# 2019-12-31         -2.354800e+10
# 2018-12-31         -2.513900e+10

# %% [markdown]
# # Yahoo Finance

# %%
my_headers = {'user-agent': 'curl/7.55.1', 'accept': 'application/json', 'content-type': 'application/json',
                          'referer': 'https://finance.yahoo.com/', 'cache-control': 'no-cache', 'connection': 'close'}

# %% [markdown]
# ## URL 1

# %%
url1 = 'https://query2.finance.yahoo.com/v10/finance/quoteSummary/GOOG?formatted=true&crumb=0z/wDTNyxte&lang=en-US&region=US&modules=incomeStatementHistory,cashflowStatementHistory,balanceSheetHistory,incomeStatementHistoryQuarterly,cashflowStatementHistoryQuarterly,balanceSheetHistoryQuarterly&corsDomain=finance.yahoo.com'

# %%
response = requests.get(url1, headers = my_headers)
response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)

# %%
data = data['quoteSummary']['result'][0]

# %%
data.keys()
# Out:
# dict_keys(['incomeStatementHistoryQuarterly', 'cashflowStatementHistory', 'cashflowStatementHistoryQuarterly', 'balanceSheetHistoryQuarterly', 'balanceSheetHistory', 'incomeStatementHistory'])

# %%
ish = data['balanceSheetHistory']['balanceSheetStatements']

# %%
ish
# Out:
# [{'maxAge': 1,
#   'endDate': {'raw': 1640908800, 'fmt': '2021-12-31'},
#   'cash': {'raw': 20945000000, 'fmt': '20.95B', 'longFmt': '20,945,000,000'},
#   'shortTermInvestments': {'raw': 118704000000,
#    'fmt': '118.7B',
#    'longFmt': '118,704,000,000'},
#   'netReceivables': {'raw': 40270000000,
#    'fmt': '40.27B',
#    'longFmt': '40,270,000,000'},
#   'inventory': {'raw': 1170000000, 'fmt': '1.17B', 'longFmt': '1,170,000,000'},
#   'otherCurrentAssets': {'raw': 7054000000,
#    'fmt': '7.05B',
#    'longFmt': '7,054,000,000'},
#   'totalCurrentAssets': {'raw': 188143000000,
#    'fmt': '188.14B',
#    'longFmt': '188,143,000,000'},
#   'longTermInvestments': {'raw': 29549000000,
#    'fmt': '29.55B',
#    'longFmt': '29,549,000,000'},
#   'propertyPlantEquipment': {'raw': 110558000000,
#    'fmt': '110.56B',
#    'longFmt': '110,558,000,000'},
#   'goodWill': {'raw': 22956000000,
#    'fmt': '22.96B',
#    'longFmt': '22,956,000,000'},
#   'intangibleAssets': {'raw': 1417000000,
#    'fmt': '1.42B',
#    'longFmt': '1,417,000,000'},
#   'otherAssets': {'raw': 6645000000,
#    'fmt': '6.64B',
#    'longFmt': '6,645,000,000'},
#   'deferredLongTermAssetCharges': {'raw': 1284000000,
#    'fmt': '1.28B',
#    'longFmt': '1,284,000,000'},
#   'totalAssets': {'raw': 359268000000,
#    'fmt': '359.27B',
#    'longFmt': '359,268,000,000'},
#   'accountsPayable': {'raw': 6037000000,
#    'fmt': '6.04B',
#    'longFmt': '6,037,000,000'},
#   'otherCurrentLiab': {'raw': 29208000000,
#    'fmt': '29.21B',
#    'longFmt': '29,208,000,000'},
#   'longTermDebt': {'raw': 12844000000,
#    'fmt': '12.84B',
#    'longFmt': '12,844,000,000'},
#   'otherLiab': {'raw': 17173000000,
#    'fmt': '17.17B',
#    'longFmt': '17,173,000,000'},
#   'totalCurrentLiabilities': {'raw': 64254000000,
#    'fmt': '64.25B',
#    'longFmt': '64,254,000,000'},
#   'totalLiab': {'raw': 107633000000,
#    'fmt': '107.63B',
#    'longFmt': '107,633,000,000'},
#   'commonStock': {'raw': 61774000000,
#    'fmt': '61.77B',
#    'longFmt': '61,774,000,000'},
#   'retainedEarnings': {'raw': 191484000000,
#    'fmt': '191.48B',
#    'longFmt': '191,484,000,000'},
#   'treasuryStock': {'raw': -1623000000,
#    'fmt': '-1.62B',
#    'longFmt': '-1,623,000,000'},
#   'otherStockholderEquity': {'raw': -1623000000,
#    'fmt': '-1.62B',
#    'longFmt': '-1,623,000,000'},
#   'totalStockholderEquity': {'raw': 251635000000,
#    'fmt': '251.63B',
#    'longFmt': '251,635,000,000'},
#   'netTangibleAssets': {'raw': 227262000000,
#    'fmt': '227.26B',
#    'longFmt': '227,262,000,000'}},
#  {'maxAge': 1,
#   'endDate': {'raw': 1609372800, 'fmt': '2020-12-31'},
#   'cash': {'raw': 26465000000, 'fmt': '26.46B', 'longFmt': '26,465,000,000'},
#   'shortTermInvestments': {'raw': 110229000000,
#    'fmt': '110.23B',
#    'longFmt': '110,229,000,000'},
#   'netReceivables': {'raw': 31384000000,
#    'fmt': '31.38B',
#    'longFmt': '31,384,000,000'},
#   'inventory': {'raw': 728000000, 'fmt': '728M', 'longFmt': '728,000,000'},
#   'otherCurrentAssets': {'raw': 5490000000,
#    'fmt': '5.49B',
#    'longFmt': '5,490,000,000'},
#   'totalCurrentAssets': {'raw': 174296000000,
#    'fmt': '174.3B',
#    'longFmt': '174,296,000,000'},
#   'longTermInvestments': {'raw': 20703000000,
#    'fmt': '20.7B',
#    'longFmt': '20,703,000,000'},
#   'propertyPlantEquipment': {'raw': 96960000000,
#    'fmt': '96.96B',
#    'longFmt': '96,960,000,000'},
#   'goodWill': {'raw': 21175000000,
#    'fmt': '21.18B',
#    'longFmt': '21,175,000,000'},
#   'intangibleAssets': {'raw': 1445000000,
#    'fmt': '1.45B',
#    'longFmt': '1,445,000,000'},
#   'otherAssets': {'raw': 5037000000,
#    'fmt': '5.04B',
#    'longFmt': '5,037,000,000'},
#   'deferredLongTermAssetCharges': {'raw': 1084000000,
#    'fmt': '1.08B',
#    'longFmt': '1,084,000,000'},
#   'totalAssets': {'raw': 319616000000,
#    'fmt': '319.62B',
#    'longFmt': '319,616,000,000'},
#   'accountsPayable': {'raw': 5589000000,
#    'fmt': '5.59B',
#    'longFmt': '5,589,000,000'},
#   'shortLongTermDebt': {'raw': 999000000,
#    'fmt': '999M',
#    'longFmt': '999,000,000'},
#   'otherCurrentLiab': {'raw': 28006000000,
#    'fmt': '28.01B',
#    'longFmt': '28,006,000,000'},
#   'longTermDebt': {'raw': 12832000000,
#    'fmt': '12.83B',
#    'longFmt': '12,832,000,000'},
#   'otherLiab': {'raw': 15160000000,
#    'fmt': '15.16B',
#    'longFmt': '15,160,000,000'},
#   'totalCurrentLiabilities': {'raw': 56834000000,
#    'fmt': '56.83B',
#    'longFmt': '56,834,000,000'},
#   'totalLiab': {'raw': 97072000000,
#    'fmt': '97.07B',
#    'longFmt': '97,072,000,000'},
#   'commonStock': {'raw': 58510000000,
#    'fmt': '58.51B',
#    'longFmt': '58,510,000,000'},
#   'retainedEarnings': {'raw': 163401000000,
#    'fmt': '163.4B',
#    'longFmt': '163,401,000,000'},
#   'treasuryStock': {'raw': 633000000, 'fmt': '633M', 'longFmt': '633,000,000'},
#   'otherStockholderEquity': {'raw': 633000000,
#    'fmt': '633M',
#    'longFmt': '633,000,000'},
#   'totalStockholderEquity': {'raw': 222544000000,
#    'fmt': '222.54B',
#    'longFmt': '222,544,000,000'},
#   'netTangibleAssets': {'raw': 199924000000,
#    'fmt': '199.92B',
#    'longFmt': '199,924,000,000'}},
#  {'maxAge': 1,
#   'endDate': {'raw': 1577750400, 'fmt': '2019-12-31'},
#   'cash': {'raw': 18498000000, 'fmt': '18.5B', 'longFmt': '18,498,000,000'},
#   'shortTermInvestments': {'raw': 101177000000,
#    'fmt': '101.18B',
#    'longFmt': '101,177,000,000'},
#   'netReceivables': {'raw': 27492000000,
#    'fmt': '27.49B',
#    'longFmt': '27,492,000,000'},
#   'inventory': {'raw': 999000000, 'fmt': '999M', 'longFmt': '999,000,000'},
#   'otherCurrentAssets': {'raw': 4412000000,
#    'fmt': '4.41B',
#    'longFmt': '4,412,000,000'},
#   'totalCurrentAssets': {'raw': 152578000000,
#    'fmt': '152.58B',
#    'longFmt': '152,578,000,000'},
#   'longTermInvestments': {'raw': 13078000000,
#    'fmt': '13.08B',
#    'longFmt': '13,078,000,000'},
#   'propertyPlantEquipment': {'raw': 84587000000,
#    'fmt': '84.59B',
#    'longFmt': '84,587,000,000'},
#   'goodWill': {'raw': 20624000000,
#    'fmt': '20.62B',
#    'longFmt': '20,624,000,000'},
#   'intangibleAssets': {'raw': 1979000000,
#    'fmt': '1.98B',
#    'longFmt': '1,979,000,000'},
#   'otherAssets': {'raw': 3063000000,
#    'fmt': '3.06B',
#    'longFmt': '3,063,000,000'},
#   'deferredLongTermAssetCharges': {'raw': 721000000,
#    'fmt': '721M',
#    'longFmt': '721,000,000'},
#   'totalAssets': {'raw': 275909000000,
#    'fmt': '275.91B',
#    'longFmt': '275,909,000,000'},
#   'accountsPayable': {'raw': 5561000000,
#    'fmt': '5.56B',
#    'longFmt': '5,561,000,000'},
#   'otherCurrentLiab': {'raw': 22159000000,
#    'fmt': '22.16B',
#    'longFmt': '22,159,000,000'},
#   'longTermDebt': {'raw': 3958000000,
#    'fmt': '3.96B',
#    'longFmt': '3,958,000,000'},
#   'otherLiab': {'raw': 14478000000,
#    'fmt': '14.48B',
#    'longFmt': '14,478,000,000'},
#   'totalCurrentLiabilities': {'raw': 45221000000,
#    'fmt': '45.22B',
#    'longFmt': '45,221,000,000'},
#   'totalLiab': {'raw': 74467000000,
#    'fmt': '74.47B',
#    'longFmt': '74,467,000,000'},
#   'commonStock': {'raw': 50552000000,
#    'fmt': '50.55B',
#    'longFmt': '50,552,000,000'},
#   'retainedEarnings': {'raw': 152122000000,
#    'fmt': '152.12B',
#    'longFmt': '152,122,000,000'},
#   'treasuryStock': {'raw': -1232000000,
#    'fmt': '-1.23B',
#    'longFmt': '-1,232,000,000'},
#   'otherStockholderEquity': {'raw': -1232000000,
#    'fmt': '-1.23B',
#    'longFmt': '-1,232,000,000'},
#   'totalStockholderEquity': {'raw': 201442000000,
#    'fmt': '201.44B',
#    'longFmt': '201,442,000,000'},
#   'netTangibleAssets': {'raw': 178839000000,
#    'fmt': '178.84B',
#    'longFmt': '178,839,000,000'}},
#  {'maxAge': 1,
#   'endDate': {'raw': 1546214400, 'fmt': '2018-12-31'},
#   'cash': {'raw': 16701000000, 'fmt': '16.7B', 'longFmt': '16,701,000,000'},
#   'shortTermInvestments': {'raw': 92439000000,
#    'fmt': '92.44B',
#    'longFmt': '92,439,000,000'},
#   'netReceivables': {'raw': 21193000000,
#    'fmt': '21.19B',
#    'longFmt': '21,193,000,000'},
#   'inventory': {'raw': 1107000000, 'fmt': '1.11B', 'longFmt': '1,107,000,000'},
#   'otherCurrentAssets': {'raw': 4236000000,
#    'fmt': '4.24B',
#    'longFmt': '4,236,000,000'},
#   'totalCurrentAssets': {'raw': 135676000000,
#    'fmt': '135.68B',
#    'longFmt': '135,676,000,000'},
#   'longTermInvestments': {'raw': 13859000000,
#    'fmt': '13.86B',
#    'longFmt': '13,859,000,000'},
#   'propertyPlantEquipment': {'raw': 59719000000,
#    'fmt': '59.72B',
#    'longFmt': '59,719,000,000'},
#   'goodWill': {'raw': 17888000000,
#    'fmt': '17.89B',
#    'longFmt': '17,888,000,000'},
#   'intangibleAssets': {'raw': 2220000000,
#    'fmt': '2.22B',
#    'longFmt': '2,220,000,000'},
#   'otherAssets': {'raw': 3430000000,
#    'fmt': '3.43B',
#    'longFmt': '3,430,000,000'},
#   'deferredLongTermAssetCharges': {'raw': 737000000,
#    'fmt': '737M',
#    'longFmt': '737,000,000'},
#   'totalAssets': {'raw': 232792000000,
#    'fmt': '232.79B',
#    'longFmt': '232,792,000,000'},
#   'accountsPayable': {'raw': 4378000000,
#    'fmt': '4.38B',
#    'longFmt': '4,378,000,000'},
#   'otherCurrentLiab': {'raw': 17612000000,
#    'fmt': '17.61B',
#    'longFmt': '17,612,000,000'},
#   'longTermDebt': {'raw': 3950000000,
#    'fmt': '3.95B',
#    'longFmt': '3,950,000,000'},
#   'otherLiab': {'raw': 16532000000,
#    'fmt': '16.53B',
#    'longFmt': '16,532,000,000'},
#   'totalCurrentLiabilities': {'raw': 34620000000,
#    'fmt': '34.62B',
#    'longFmt': '34,620,000,000'},
#   'totalLiab': {'raw': 55164000000,
#    'fmt': '55.16B',
#    'longFmt': '55,164,000,000'},
#   'commonStock': {'raw': 45049000000,
#    'fmt': '45.05B',
#    'longFmt': '45,049,000,000'},
#   'retainedEarnings': {'raw': 134885000000,
#    'fmt': '134.88B',
#    'longFmt': '134,885,000,000'},
#   'treasuryStock': {'raw': -2306000000,
#    'fmt': '-2.31B',
#    'longFmt': '-2,306,000,000'},
#   'otherStockholderEquity': {'raw': -2306000000,
#    'fmt': '-2.31B',
#    'longFmt': '-2,306,000,000'},
#   'totalStockholderEquity': {'raw': 177628000000,
#    'fmt': '177.63B',
#    'longFmt': '177,628,000,000'},
#   'netTangibleAssets': {'raw': 157520000000,
#    'fmt': '157.52B',
#    'longFmt': '157,520,000,000'}}]

# %%
date = ish['endDate']['fmt']

# %%
test = Ticker('GOOG')
columns = test.get_cashflows().T.columns

# %%
np.sort(np.array(list(columns)))
# Out:
# array(['Capital Expenditures', 'Change In Cash',
#        'Change To Account Receivables', 'Change To Liabilities',
#        'Change To Netincome', 'Change To Operating Activities',
#        'Depreciation', 'Effect Of Exchange Rate', 'Investments',
#        'Net Borrowings', 'Net Income',
#        'Other Cashflows From Financing Activities',
#        'Other Cashflows From Investing Activities', 'Repurchase Of Stock',
#        'Total Cash From Financing Activities',
#        'Total Cash From Operating Activities',
#        'Total Cashflows From Investing Activities'], dtype='<U41')

# %%
np.sort(np.array(list(ish.keys())))
# Out:
# array(['capitalExpenditures', 'changeInCash',
#        'changeToAccountReceivables', 'changeToLiabilities',
#        'changeToNetincome', 'changeToOperatingActivities', 'depreciation',
#        'effectOfExchangeRate', 'endDate', 'investments', 'maxAge',
#        'netBorrowings', 'netIncome',
#        'otherCashflowsFromFinancingActivities',
#        'otherCashflowsFromInvestingActivities', 'repurchaseOfStock',
#        'totalCashFromFinancingActivities',
#        'totalCashFromOperatingActivities',
#        'totalCashflowsFromInvestingActivities'], dtype='<U37')

# %%
infoOfInterest = ['totalRevenue', 
                  'costOfRevenue', 
                  'grossProfit',
                  'researchDevelopment',
                  'sellingGeneralAdministrative',
                  'otherOperatingExpenses',
                  'totalOperatingExpenses',
                  'operatingIncome',

# %%
ish
# Out:
# {'maxAge': 1,
#  'endDate': {'raw': 1640908800, 'fmt': '2021-12-31'},
#  'totalRevenue': {'raw': 257637000000,
#   'fmt': '257.64B',
#   'longFmt': '257,637,000,000'},
#  'costOfRevenue': {'raw': 110939000000,
#   'fmt': '110.94B',
#   'longFmt': '110,939,000,000'},
#  'grossProfit': {'raw': 146698000000,
#   'fmt': '146.7B',
#   'longFmt': '146,698,000,000'},
#  'researchDevelopment': {'raw': 31562000000,
#   'fmt': '31.56B',
#   'longFmt': '31,562,000,000'},
#  'sellingGeneralAdministrative': {'raw': 36422000000,
#   'fmt': '36.42B',
#   'longFmt': '36,422,000,000'},
#  'nonRecurring': {},
#  'otherOperatingExpenses': {},
#  'totalOperatingExpenses': {'raw': 178923000000,
#   'fmt': '178.92B',
#   'longFmt': '178,923,000,000'},
#  'operatingIncome': {'raw': 78714000000,
#   'fmt': '78.71B',
#   'longFmt': '78,714,000,000'},
#  'totalOtherIncomeExpenseNet': {'raw': 12020000000,
#   'fmt': '12.02B',
#   'longFmt': '12,020,000,000'},
#  'ebit': {'raw': 78714000000, 'fmt': '78.71B', 'longFmt': '78,714,000,000'},
#  'interestExpense': {'raw': -346000000,
#   'fmt': '-346M',
#   'longFmt': '-346,000,000'},
#  'incomeBeforeTax': {'raw': 90734000000,
#   'fmt': '90.73B',
#   'longFmt': '90,734,000,000'},
#  'incomeTaxExpense': {'raw': 14701000000,
#   'fmt': '14.7B',
#   'longFmt': '14,701,000,000'},
#  'minorityInterest': {},
#  'netIncomeFromContinuingOps': {'raw': 76033000000,
#   'fmt': '76.03B',
#   'longFmt': '76,033,000,000'},
#  'discontinuedOperations': {},
#  'extraordinaryItems': {},
#  'effectOfAccountingCharges': {},
#  'otherItems': {},
#  'netIncome': {'raw': 76033000000,
#   'fmt': '76.03B',
#   'longFmt': '76,033,000,000'},
#  'netIncomeApplicableToCommonShares': {'raw': 76033000000,
#   'fmt': '76.03B',
#   'longFmt': '76,033,000,000'}}

# %% [markdown]
# ## URL 2

# %%
url2 = 'https://query1.finance.yahoo.com/ws/fundamentals-timeseries/v1/finance/timeseries/GOOG?lang=en-US&region=US&symbol=GOOG&padTimeSeries=true&type=annualTaxEffectOfUnusualItems%2CtrailingTaxEffectOfUnusualItems%2CannualTaxRateForCalcs%2CtrailingTaxRateForCalcs%2CannualNormalizedEBITDA%2CtrailingNormalizedEBITDA%2CannualNormalizedDilutedEPS%2CtrailingNormalizedDilutedEPS%2CannualNormalizedBasicEPS%2CtrailingNormalizedBasicEPS%2CannualTotalUnusualItems%2CtrailingTotalUnusualItems%2CannualTotalUnusualItemsExcludingGoodwill%2CtrailingTotalUnusualItemsExcludingGoodwill%2CannualNetIncomeFromContinuingOperationNetMinorityInterest%2CtrailingNetIncomeFromContinuingOperationNetMinorityInterest%2CannualReconciledDepreciation%2CtrailingReconciledDepreciation%2CannualReconciledCostOfRevenue%2CtrailingReconciledCostOfRevenue%2CannualEBITDA%2CtrailingEBITDA%2CannualEBIT%2CtrailingEBIT%2CannualNetInterestIncome%2CtrailingNetInterestIncome%2CannualInterestExpense%2CtrailingInterestExpense%2CannualInterestIncome%2CtrailingInterestIncome%2CannualContinuingAndDiscontinuedDilutedEPS%2CtrailingContinuingAndDiscontinuedDilutedEPS%2CannualContinuingAndDiscontinuedBasicEPS%2CtrailingContinuingAndDiscontinuedBasicEPS%2CannualNormalizedIncome%2CtrailingNormalizedIncome%2CannualNetIncomeFromContinuingAndDiscontinuedOperation%2CtrailingNetIncomeFromContinuingAndDiscontinuedOperation%2CannualTotalExpenses%2CtrailingTotalExpenses%2CannualRentExpenseSupplemental%2CtrailingRentExpenseSupplemental%2CannualReportedNormalizedDilutedEPS%2CtrailingReportedNormalizedDilutedEPS%2CannualReportedNormalizedBasicEPS%2CtrailingReportedNormalizedBasicEPS%2CannualTotalOperatingIncomeAsReported%2CtrailingTotalOperatingIncomeAsReported%2CannualDividendPerShare%2CtrailingDividendPerShare%2CannualDilutedAverageShares%2CtrailingDilutedAverageShares%2CannualBasicAverageShares%2CtrailingBasicAverageShares%2CannualDilutedEPS%2CtrailingDilutedEPS%2CannualDilutedEPSOtherGainsLosses%2CtrailingDilutedEPSOtherGainsLosses%2CannualTaxLossCarryforwardDilutedEPS%2CtrailingTaxLossCarryforwardDilutedEPS%2CannualDilutedAccountingChange%2CtrailingDilutedAccountingChange%2CannualDilutedExtraordinary%2CtrailingDilutedExtraordinary%2CannualDilutedDiscontinuousOperations%2CtrailingDilutedDiscontinuousOperations%2CannualDilutedContinuousOperations%2CtrailingDilutedContinuousOperations%2CannualBasicEPS%2CtrailingBasicEPS%2CannualBasicEPSOtherGainsLosses%2CtrailingBasicEPSOtherGainsLosses%2CannualTaxLossCarryforwardBasicEPS%2CtrailingTaxLossCarryforwardBasicEPS%2CannualBasicAccountingChange%2CtrailingBasicAccountingChange%2CannualBasicExtraordinary%2CtrailingBasicExtraordinary%2CannualBasicDiscontinuousOperations%2CtrailingBasicDiscontinuousOperations%2CannualBasicContinuousOperations%2CtrailingBasicContinuousOperations%2CannualDilutedNIAvailtoComStockholders%2CtrailingDilutedNIAvailtoComStockholders%2CannualAverageDilutionEarnings%2CtrailingAverageDilutionEarnings%2CannualNetIncomeCommonStockholders%2CtrailingNetIncomeCommonStockholders%2CannualOtherunderPreferredStockDividend%2CtrailingOtherunderPreferredStockDividend%2CannualPreferredStockDividends%2CtrailingPreferredStockDividends%2CannualNetIncome%2CtrailingNetIncome%2CannualMinorityInterests%2CtrailingMinorityInterests%2CannualNetIncomeIncludingNoncontrollingInterests%2CtrailingNetIncomeIncludingNoncontrollingInterests%2CannualNetIncomeFromTaxLossCarryforward%2CtrailingNetIncomeFromTaxLossCarryforward%2CannualNetIncomeExtraordinary%2CtrailingNetIncomeExtraordinary%2CannualNetIncomeDiscontinuousOperations%2CtrailingNetIncomeDiscontinuousOperations%2CannualNetIncomeContinuousOperations%2CtrailingNetIncomeContinuousOperations%2CannualEarningsFromEquityInterestNetOfTax%2CtrailingEarningsFromEquityInterestNetOfTax%2CannualTaxProvision%2CtrailingTaxProvision%2CannualPretaxIncome%2CtrailingPretaxIncome%2CannualOtherIncomeExpense%2CtrailingOtherIncomeExpense%2CannualOtherNonOperatingIncomeExpenses%2CtrailingOtherNonOperatingIncomeExpenses%2CannualSpecialIncomeCharges%2CtrailingSpecialIncomeCharges%2CannualGainOnSaleOfPPE%2CtrailingGainOnSaleOfPPE%2CannualGainOnSaleOfBusiness%2CtrailingGainOnSaleOfBusiness%2CannualOtherSpecialCharges%2CtrailingOtherSpecialCharges%2CannualWriteOff%2CtrailingWriteOff%2CannualImpairmentOfCapitalAssets%2CtrailingImpairmentOfCapitalAssets%2CannualRestructuringAndMergernAcquisition%2CtrailingRestructuringAndMergernAcquisition%2CannualSecuritiesAmortization%2CtrailingSecuritiesAmortization%2CannualEarningsFromEquityInterest%2CtrailingEarningsFromEquityInterest%2CannualGainOnSaleOfSecurity%2CtrailingGainOnSaleOfSecurity%2CannualNetNonOperatingInterestIncomeExpense%2CtrailingNetNonOperatingInterestIncomeExpense%2CannualTotalOtherFinanceCost%2CtrailingTotalOtherFinanceCost%2CannualInterestExpenseNonOperating%2CtrailingInterestExpenseNonOperating%2CannualInterestIncomeNonOperating%2CtrailingInterestIncomeNonOperating%2CannualOperatingIncome%2CtrailingOperatingIncome%2CannualOperatingExpense%2CtrailingOperatingExpense%2CannualOtherOperatingExpenses%2CtrailingOtherOperatingExpenses%2CannualOtherTaxes%2CtrailingOtherTaxes%2CannualProvisionForDoubtfulAccounts%2CtrailingProvisionForDoubtfulAccounts%2CannualDepreciationAmortizationDepletionIncomeStatement%2CtrailingDepreciationAmortizationDepletionIncomeStatement%2CannualDepletionIncomeStatement%2CtrailingDepletionIncomeStatement%2CannualDepreciationAndAmortizationInIncomeStatement%2CtrailingDepreciationAndAmortizationInIncomeStatement%2CannualAmortization%2CtrailingAmortization%2CannualAmortizationOfIntangiblesIncomeStatement%2CtrailingAmortizationOfIntangiblesIncomeStatement%2CannualDepreciationIncomeStatement%2CtrailingDepreciationIncomeStatement%2CannualResearchAndDevelopment%2CtrailingResearchAndDevelopment%2CannualSellingGeneralAndAdministration%2CtrailingSellingGeneralAndAdministration%2CannualSellingAndMarketingExpense%2CtrailingSellingAndMarketingExpense%2CannualGeneralAndAdministrativeExpense%2CtrailingGeneralAndAdministrativeExpense%2CannualOtherGandA%2CtrailingOtherGandA%2CannualInsuranceAndClaims%2CtrailingInsuranceAndClaims%2CannualRentAndLandingFees%2CtrailingRentAndLandingFees%2CannualSalariesAndWages%2CtrailingSalariesAndWages%2CannualGrossProfit%2CtrailingGrossProfit%2CannualCostOfRevenue%2CtrailingCostOfRevenue%2CannualTotalRevenue%2CtrailingTotalRevenue%2CannualExciseTaxes%2CtrailingExciseTaxes%2CannualOperatingRevenue%2CtrailingOperatingRevenue&merge=false&period1=493590046&period2=1665835809&corsDomain=finance.yahoo.com'

# %%
response = requests.get(url2, headers = my_headers)
response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)

# %%
data = data['timeseries']['result']

# %%
dataAnnualDict = dict()
dataTTMDict = dict()
dataNoneDict = dict()

for dataKPI in data:

    try:
        type = dataKPI['meta']['type'][0]
        dataKPI = dataKPI[type]
        
        dataKPIDict = defaultdict(list)
        date = list()
        
        for dataKPI_date in dataKPI:
            dataKPIDict[type].append(dataKPI_date['reportedValue']['raw'])
            date.append(dataKPI_date['asOfDate'])
        
        if dataKPI[0]['periodType'] == '12M':
            dataAnnualDict[type] = {'df': pd.DataFrame(dataKPIDict),
                                    'date': pd.Series(date)}
            
        elif dataKPI[0]['periodType'] == 'TTM':
            dataTTMDict[type] = {'df': pd.DataFrame(dataKPIDict),
                                 'date': pd.Series(date)}
        
    except:
        dataNoneDict[type] = None

# %% [markdown]
# ## Data Annual

# %%
dataAnnual = pd.concat([dataKPI['df'] for dataKPI in dataAnnualDict.values()], axis = 1)

# %%
keys = list(dataAnnualDict.keys())
date = dataAnnualDict[keys[0]]['date']
date.name = 'date'

dataAnnual = pd.concat([date, dataAnnual], axis = 1)

# %%
dataAnnual
# Out:
#          date  annualOtherIncomeExpense  annualGrossProfit  \
# 0  2018-12-31              1.757000e+09       7.727000e+10
# 1  2019-12-31              1.370000e+09       8.996100e+10
# 2  2020-12-31              5.128000e+09       9.779500e+10
# 3  2021-12-31              1.086700e+10       1.466980e+11
#
#    annualResearchAndDevelopment  annualNormalizedIncome  \
# 0                  2.141900e+10            2.941688e+10
# 1                  2.601800e+10            3.329913e+10
# 2                  2.757300e+10            3.526363e+10
# 3                  3.156200e+10            6.595186e+10
#
#    annualSellingAndMarketingExpense  annualGainOnSaleOfSecurity  \
# 0                      1.633300e+10                6.570000e+09
# 1                      1.846400e+10                2.901000e+09
# 2                      1.794600e+10                5.973000e+09
# 3                      2.291200e+10                1.203000e+10
#
#    annualInterestExpenseNonOperating  \
# 0                        114000000.0
# 1                        100000000.0
# 2                        135000000.0
# 3                        346000000.0
#
#    annualNetNonOperatingInterestIncomeExpense  annualReconciledCostOfRevenue  \
# 0                                1.764000e+09                   5.954900e+10
# 1                                2.327000e+09                   7.189600e+10
# 2                                1.730000e+09                   8.473200e+10
# 3                                1.153000e+09                   1.109390e+11
#
#    ...  annualSpecialIncomeCharges  \
# 0  ...               -5.071000e+09
# 1  ...               -1.697000e+09
# 2  ...                0.000000e+00
# 3  ...                0.000000e+00
#
#    annualNetIncomeIncludingNoncontrollingInterests  annualTaxProvision  \
# 0                                     3.073600e+10        4.177000e+09
# 1                                     3.434300e+10        5.282000e+09
# 2                                     4.026900e+10        7.813000e+09
# 3                                     7.603300e+10        1.470100e+10
#
#    annualNetIncomeCommonStockholders  annualInterestExpense  \
# 0                       3.073600e+10            114000000.0
# 1                       3.434300e+10            100000000.0
# 2                       4.026900e+10            135000000.0
# 3                       7.603300e+10            346000000.0
#
#    annualReconciledDepreciation  annualTotalRevenue  annualBasicEPS  \
# 0                  9.035000e+09        1.368190e+11        2.211001
# 1                  1.178100e+10        1.618570e+11        2.479501
# 2                  1.369700e+10        1.825270e+11        2.957501
# 3                  1.244100e+10        2.576370e+11        5.694003
#
#    annualTaxRateForCalcs  \
# 0                  0.120
# 1                  0.133
# 2                  0.162
# 3                  0.162
#
#    annualNetIncomeFromContinuingOperationNetMinorityInterest
# 0                                       3.073600e+10
# 1                                       3.434300e+10
# 2                                       4.026900e+10
# 3                                       7.603300e+10
#
# [4 rows x 47 columns]

# %% [markdown]
# ## Data TTM

# %%
dataTTM = pd.concat([dataKPI['df'] for dataKPI in dataTTMDict.values()], axis = 1)

# %%
keys = list(dataTTMDict.keys())
date = dataTTMDict[keys[0]]['date']
date.name = 'date'

keys = list(dataTTMDict.keys())
ggggggggggdate = dataTTMDict[keys[0]]['date']
ggggggggggdate.name = 'date'
gggggggggg
gdataTTM = pd.concat([date, dataTTM], axis = 1)

# %%
dataTTM
# Out:
#          date  trailingNormalizedIncome  trailingGrossProfit  \
# 0  2022-06-30              7.073190e+10         1.578270e+11
#
#    trailingSellingAndMarketingExpense  trailingGainOnSaleOfSecurity  \
# 0                        2.557500e+10                  1.523000e+09
#
#    trailingOtherGandA  trailingCostOfRevenue  trailingTotalRevenue  \
# 0        1.442700e+10           1.203120e+11          2.781390e+11
#
#    trailingNetIncome  trailingTaxProvision  ...  trailingTaxRateForCalcs  \
# 0       7.201600e+10          1.339800e+10  ...                  0.15686
#
#    trailingNetIncomeCommonStockholders  \
# 0                         7.201600e+10
#
#    trailingDilutedNIAvailtoComStockholders  trailingTaxEffectOfUnusualItems  \
# 0                             7.173600e+10                     2.388971e+08
#
#    trailingTotalOperatingIncomeAsReported  trailingOperatingRevenue  \
# 0                            8.246300e+10              2.781390e+11
#
#    trailingResearchAndDevelopment  trailingEBITDA  \
# 0                    3.536200e+10    1.001980e+11
#
#    trailingNetNonOperatingInterestIncomeExpense  trailingInterestIncome
# 0                                  1.305000e+09            1.665000e+09
#
# [1 rows x 43 columns]

# %% [markdown]
# # URL 3

# %%
url3 = 'https://finance.yahoo.com/quote/GOOG/key-statistics?p=GOOG'

# %%
response = requests.get(url3, headers = my_headers)
response
# Out:
# <Response [200]>

# %%
p = re.compile(r'root\.App\.main = (.*);')

# %%
data = json.loads(p.findall(response.text)[0])
