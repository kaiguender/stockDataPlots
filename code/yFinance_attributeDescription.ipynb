# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd

from yfinance import *

# %% [markdown]
# ## yFinance

# %%
tickerGoogle = Ticker('GOOG')

# %%
# Attributes starting with '_' and containing useful information

['_base_url', # URL used for scraping 
 '_get_ticker_tz()', # listing location (e.g. 'America/New_York')
 '_options2df()', # seems transform data of trading info
 '_tz', # timezone (but more like city location). Seems to be needed for some functions like _options2df()
]

# %%
['actions', # date of stock splits and dividends including the action
 'analysis', # Df containing Growth estimates over time etc.
 'balancesheet', # yearly data
 'calendar', # Future earnings date, seems to be somewhat flawed
 'cashflow', # yearly data
 'dividends', # time series of dividend payments. Empty if no dividends have been payed
 'earnings', # Just revenue and earnings for whole years (4 years)
 'earnings_dates', # Past earnings dates with EPS-Estimate vs. Reported-EPS
 'financials', # Unordered df of GuV info. Can contain 'None'-entries. Always the same structure for all stocks?
 'info', # A massive load of information about the company like a business summary, number of employees, KPIs, PE-Ratio etc.
 'institutional_holders', # Top 10
 'major_holders', # Stock ownership in terms of Intitutions and Insiders
 'mutualfund_holders', # Top 10
 'option_chain', # represents data about the currently traded options. Is its own data-type created by yFinance
 'quarterly_balancesheet', 
 'quarterly_cashflow',
 'quarterly_earnings',
 'quarterly_financials', # same as 'financials'
 'recommendations', # Analyst Ratings
 'shares', # Share Count at the end of different years
 'splits', # Series depicting historic stock splits
 'ticker', # Just like the input
]
# Out:
#   Input In [40]
#     'ticker',
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
test = getattr(tickerGoogle, 'financials')
test
# Out:
#                                             2021-12-31      2020-12-31  \
# Research Development                     31562000000.0   27573000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        90734000000.0   48082000000.0
# Minority Interest                                 None            None
# Net Income                               76033000000.0   40269000000.0
# Selling General Administrative           36422000000.0   28998000000.0
# Gross Profit                            146698000000.0   97795000000.0
# Ebit                                     78714000000.0   41224000000.0
# Operating Income                         78714000000.0   41224000000.0
# Other Operating Expenses                          None            None
# Interest Expense                          -346000000.0    -135000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                       14701000000.0    7813000000.0
# Total Revenue                           257637000000.0  182527000000.0
# Total Operating Expenses                178923000000.0  141303000000.0
# Cost Of Revenue                         110939000000.0   84732000000.0
# Total Other Income Expense Net           12020000000.0    6858000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           76033000000.0   40269000000.0
# Net Income Applicable To Common Shares   76033000000.0   40269000000.0
#
#                                             2019-12-31      2018-12-31
# Research Development                     26018000000.0   21419000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        39625000000.0   34913000000.0
# Minority Interest                                 None            None
# Net Income                               34343000000.0   30736000000.0
# Selling General Administrative           28015000000.0   23256000000.0
# Gross Profit                             89961000000.0   77270000000.0
# Ebit                                     35928000000.0   32595000000.0
# Operating Income                         35928000000.0   32595000000.0
# Other Operating Expenses                          None            None
# Interest Expense                          -100000000.0    -114000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        5282000000.0    4177000000.0
# Total Revenue                           161857000000.0  136819000000.0
# Total Operating Expenses                125929000000.0  104224000000.0
# Cost Of Revenue                          71896000000.0   59549000000.0
# Total Other Income Expense Net            3697000000.0    2318000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           34343000000.0   30736000000.0
# Net Income Applicable To Common Shares   34343000000.0   30736000000.0
